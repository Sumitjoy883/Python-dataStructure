# %% [markdown]
# # Data Types and Structures Questions

# %% [markdown]
# # Q1.What are data structures, and why are they important?
# ## What are Data Structures?
# A data structure is a way of organizing, storing, and managing data efficiently to perform operations like searching, sorting, and modifying data easily.
#
# ## Why are Data Structures Important?
# - Efficient Data Management – Helps in storing and retrieving data effectively.
# - Optimized Performance – Enables faster execution of algorithms (e.g., - - - -
# - searching in a sorted array vs. unsorted array).
# - Memory Efficiency – Reduces unnecessary memory usage by using the       right data structure.
# - Code Organization – Makes the code more readable and manageable.

# %% [markdown]
# # Q2. Explain the difference between mutable and immutable data types with examples?

# %%
## 1. Mutable Data Types
These are data types whose values can be changed (modified) after creation without changing their identity (memory address).


## 2. Immutable Data Types
These are data types whose values cannot be changed after creation. Any modification creates a new object in memory.



## Mutable Data Types Example
my_list = [1, 2, 3]
print(id(my_list))  # Memory address before modification

my_list.append(4)  # Modifying the list
print(my_list)  # Output: [1, 2, 3, 4]
print(id(my_list))  # Memory address remains the same


## immutable Data Types Example
x = 10
print(id(x))  # Memory address before modification

x = x + 5  # Modifying the value
print(x)  # Output: 15
print(id(x))  # Memory address changes

# %% [markdown]
# # Q3. What are the main differences between lists and tuples in Python?
#
# ##. 1. Mutability
# - List → Mutable (can be modified after creation)
# - Tuple → Immutable (cannot be modified after creation)
#
# ## 2. Syntax
# - List → Created using square brackets [ ]
# - Tuple → Created using parentheses ( )
#
# ## 3. Performance
# - Lists → are slower because they allow modifications.
# - Tuples → are faster because they are immutable, making them more memory-efficient.
#
# ## 4. Memory Usage
# - Lists → consume more memory since they need space for dynamic resizing.
# - Tuples → consume less memory as they are fixed-size and require less overhead.

# %% [markdown]
# # Q4. Describe how dictionaries store data?
# ## How Dictionaries Store Data (Simple Explanation)
#   A dictionary in Python is like a locker system where:
#
# -Each key is a unique locker number.
# - Each value is the item stored inside that locker.
# # How it Works Internally?
# 1. Keys are converted into numbers (hash values) using a function.
# 2. Python finds a specific location (index) in memory to store the key-value pair.
# 3. When you search for a key, Python quickly looks up the memory location and retrieves the value.

# %% [markdown]
# #Q5. Why might you use a set instead of a list in Python?
#
# ## 1. No Duplicates
# - Set → Automatically removes duplicates.
# - List → Can have duplicates.
#
#
# ## 2. Faster Lookups
# - Set → Faster when checking if an item is in the collection.
# - List → Slower lookups because it checks each item one by one.
#
#
# ## 3.Set Operations
# - Set → You can easily perform operations like union (combine sets) or intersection (find common items).
# - List → You need extra steps for similar operations.
#
# ## 4. No Order
# - Set → Doesn’t keep items in any specific order.
# - List → Keeps items in the order you add them.

# %% [markdown]
# # Q6.What is a string in Python, and how is it different from a list?
# ## What is a String in Python?
# A string in Python is a sequence of characters enclosed in quotes (either single ' or double "). It is used to represent text in Python.
#
# ## How is a String Different from a List?
# While both strings and lists are ordered collections, they have some key differences:
#
# 1. Data Types Inside
# - String → Can only store characters (text).
# - List → Can store different data types (numbers, strings, etc.).
#
# 2. Mutability
# - String → Immutable, meaning you cannot change a character in a string once it’s created.
#
# - List → Mutable, meaning you can change, add, or remove elements.
#
# 3. Operations
# - String → You can concatenate strings or repeat them, but you can’t modify individual characters.
#
# - List → You can perform many operations like adding/removing elements and changing individual items.
#
# 4. Usage
# -  String → Primarily used to represent text.
# - List → Used to store a collection of items that can be of different types.

# %% [markdown]
# #Q7.  How do tuples ensure data integrity in Python?
# A tuple in Python is immutable, meaning its values cannot be changed after creation. This ensures data integrity in the following ways:
# - Prevents Accidental Modification
# - Safe for Hashing (Used in Dictionaries & Sets)
# -  Improves Performance
# - Reliable Data Storage

# %% [markdown]
# #Q8.  What is a hash table, and how does it relate to dictionaries in Python?
# A hash table is a data structure that stores key-value pairs using a hashing function to quickly find values. It allows fast lookups, insertions, and deletions.

# %% [markdown]
# #Q9. Can lists contain different data types in Python?
# Yes

# %% [markdown]
# #Q10 Explain why strings are immutable in Python?

# %% [markdown]
# #Q10.What advantages do dictionaries offer over lists for certain tasks?
# Dictionaries (dict) and lists (list) are both used for storing data, but dictionaries have some key advantages for certain tasks.
#
# 1. Faster Lookups (O(1) vs. O(n))
# - Dictionaries use hash tables, so they provide fast key-based access (O(1) time).
#
# - Lists require a linear search (O(n) time), which is slower for large datasets.
#
# 2. Key-Value Pair Storage
# - Dictionaries store data in a structured way using keys and values.
# - Lists store items in an ordered way, making access index-based

# %% [markdown]
# #Q11.  Describe a scenario where using a tuple would be preferable over a list
# Scenario: Storing GPS Coordinates
# A tuple is preferable over a list when storing GPS coordinates (latitude, longitude) because:
# - The values should not change (immutability ensures data integrity).
# - Less memory usage than a list.
# -  Can be used as a dictionary key (lists cannot).
#
# ### Example
# location = (28.7041, 77.1025)  # Latitude, Longitude (Delhi, India)
# location_list = [28.7041, 77.1025]
# location_list[0] = 35.6895  # ❌ Error: Accidental change alters the data!

# %% [markdown]
# #Q13.How do sets handle duplicate values in Python?
# A set in Python automatically removes duplicate values because it only stores unique elements.
#
# ### How It Works:
# - When you add elements to a set, Python checks for duplicates.
# - If a duplicate is found, it is ignored (not added).
# - No extra effort is needed—Python ensures uniqueness automatically! 🚀

# %% [markdown]
# #Q14.How does the “in” keyword work differently for lists and dictionaries3
# The in keyword is used to check membership in both lists and dictionaries, but it works differently:
#
# ### In Lists
# - Checks if an item exists in the list.
# - Slower because it searches one by one (linear search).
#
# ###  In Dictionaries
# - Checks if a key exists (not values).
# - Faster because dictionaries use a hash table for quick lookup.
